# %% [markdown]
# # Basis for mobility analysis
#
# based on osnmx, grapphoper and movingpandas
# goals of the tutorial
#
# - basic concepts of network analysis
# - routing
# - bearing
# - isochrones
# - GPX format
# - mapmatching
# - analysis of movements
#
# based on the open data of:
# - OpenStreetMap
#
# requirements
# - python knowledge
# - geopandas
# - openstreetmap
#
# status<br/>
# “Where's Wally?”

# %% [markdown]
# ---
#
# # Setup
# for this tutorial we will use [OSMnx](https://github.com/gboeing/osmnx) = (openstreetmap + [networkx](https://networkx.org/))
#
# Boeing, G. 2017. "[OSMnx: New Methods for Acquiring, Constructing, Analyzing, and Visualizing Complex Street Networks.](https://geoffboeing.com/publications/osmnx-complex-street-networks/)" *Computers, Environment and Urban Systems 65, 126-139. doi:10.1016/j.compenvurbsys.2017.05.004*

# %%
try:
    import pygeos
except ModuleNotFoundError as e:
    # !pip install pygeos==0.14
    import pygeos

# %% [markdown]
# ... and now we can install OSMnx

# %%
try:
    import osmnx  as ox
except ModuleNotFoundError as e:
    # !pip install osmnx==1.6.0
    import osmnx  as ox
if ox.__version__ != "1.6.0":
    # !pip install -U osmnx==1.6.0
    import osmnx  as ox

# %% [markdown]
# ... and all the other packages needed for this lecture

# %%
try:
    import mapclassify
except ModuleNotFoundError as e:
    # !pip install mapclassify
    import mapclassify

if mapclassify.__version__ != "2.6.0":
  # !pip install -U mapclassify==2.6.0

# %%
import geopandas as gpd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Let’s start with OSMnx

# %%
import osmnx as ox
import matplotlib.pyplot as plt

# %% [markdown]
# ## prepare the data

# %% [markdown]
# ... we can choose the same city used on the last tutorial
#
# [Venice in Italy](https://www.openstreetmap.org/relation/44230)

# %%
place_name = "Venezia, Lido, Venice, Venezia, Veneto, Italy"

# %% [markdown]
# .. and we can extract all the streets where it's possible to drive
#
# OSMnx creates a overpass query to ask the data inside the area of name of the city and collect all the [highways](https://wiki.openstreetmap.org/wiki/Key:highway) where a car can move
#
# Eg.<br/>
# https://overpass-turbo.eu/s/1nnv
#
# ![](https://raw.githubusercontent.com/napo/geospatial_course_unitn/master/images/mezzolombardo_streets.png)

# %%
G = ox.graph_from_place(place_name, network_type='all')

# %% [markdown]
# OSMnx transform the data from OpenStreetMap in [graph](https://networkx.org/documentation/stable/reference/introduction.html#graphs) for [networkx](https://networkx.org/)

# %% [markdown]
# # Graph Theory
# text from [wikipedia](https://en.wikipedia.org/wiki/Graph_theory)
#
#
#
# A graph is made up of **vertices** (also called *nodes* or *points*) which are connected by **edges** (also called *links* or *lines*)
#
# A distinction is made between undirected graphs, where edges link two vertices symmetrically, and directed graphs, where edges link two vertices asymmetrically;
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/b/bf/Undirected.svg/267px-Undirected.svg.png)
#
# Example<br/>
# undirected graph with three nodes and three edges.
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/a/a2/Directed.svg/267px-Directed.svg.png)
#
# Example<br/>
# a directed graph with three vertices and four directed edges<br/>(the double arrow represents an edge in each direction).

# %% [markdown]
# the type of graph generated by OSMnx is a MultiDiGraph: a directed graphs with self loops and parallel edges
#
# more information [here](https://networkx.org/documentation/stable/reference/classes/multidigraph.html)

# %%
type(G)
# Out:
# networkx.classes.multidigraph.MultiDiGraph

# %% [markdown]
# OSMnx converts the graph from latitude/longitude (WGS83) to the right UTM coordinate reference system for the area selected

# %%
G_proj = ox.project_graph(G)

# %% [markdown]
# from osmnx you can create geodataframes (gdfs) from a netxworkx Graph

# %%
gdfs = ox.graph_to_gdfs(G_proj)

# %%
type(gdfs)
# Out:
# tuple

# %% [markdown]
# 0 => nodes (points)<br/>
# 1 => edges (lines)

# %%
type(gdfs[0])
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
gdfs[0].geometry.type.unique()
# Out:
# array(['Point'], dtype=object)

# %%
gdfs[1].geometry.type.unique()
# Out:
# array(['LineString'], dtype=object)

# %%
gdfs[1].crs
# Out:
# <Derived Projected CRS: +proj=utm +zone=33 +ellps=WGS84 +datum=WGS84 +unit ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 33N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# extract only the nodes (projected)

# %%
nodes_proj = ox.graph_to_gdfs(G_proj, edges=False, nodes=True)

# %%
type(nodes_proj)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
nodes_proj.crs
# Out:
# <Derived Projected CRS: +proj=utm +zone=33 +ellps=WGS84 +datum=WGS84 +unit ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: UTM zone 33N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
nodes_proj.plot()
plt.show()

# %%
lines_proj = ox.graph_to_gdfs(G_proj, nodes=False)

# %%
lines_proj.plot()
plt.show()

# %% [markdown]
# ... and we can use it as a normal geodaframe<br/>
#
# Eg:<br/>
# what sized area does our network cover in square meters?

# %%
nodes_proj.unary_union.convex_hull
# Out:
# <POLYGON ((293916.97 5033563.196, 293771.462 5033570.535, 293752.266 5033571...>

# %%
graph_area_m = nodes_proj.unary_union.convex_hull.area
graph_area_m
# Out:
# 7367792.137678296

# %% [markdown]
# with OSMnx we can extract some basic statistics

# %%
ox.basic_stats(G_proj, area=graph_area_m, clean_int_tol=15)
# Out:
# {'n': 5282,
#  'm': 13435,
#  'k_avg': 5.087088224157516,
#  'edge_length_total': 368724.9659999998,
#  'edge_length_avg': 27.44510353554148,
#  'streets_per_node_avg': 2.5759182127981823,
#  'streets_per_node_counts': {0: 0,
#   1: 1382,
#   2: 3,
#   3: 3409,
#   4: 461,
#   5: 18,
#   6: 6,
#   7: 3},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.26164331692540704,
#   2: 0.0005679666792881485,
#   3: 0.645399469897766,
#   4: 0.08727754638394547,
#   5: 0.0034078000757288905,
#   6: 0.001135933358576297,
#   7: 0.0005679666792881485},
#  'intersection_count': 3900,
#  'street_length_total': 186563.22200000013,
#  'street_segment_count': 6782,
#  'street_length_avg': 27.5085847832498,
#  'circuity_avg': 1.0625537027265872,
#  'self_loop_proportion': 0.0032438808611029196,
#  'clean_intersection_count': 670,
#  'node_density_km': 716.9040468701984,
#  'intersection_density_km': 529.3308941298321,
#  'edge_density_km': 50045.51690789022,
#  'street_density_km': 25321.455670000625,
#  'clean_intersection_density_km': 90.93633309409937}

# %% [markdown]
# stats documentation: [https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.stats](https://osmnx.readthedocs.io/en/stable/osmnx.html#module-osmnx.stats)

# %% [markdown]
# ## Glossary of the terms used by the statistics
#
# For a complete list look the [networkx documentation](https://networkx.org/documentation/stable/)
#
# - **density**<br/>defines the density of a graph. The density is 0 for a graph without edges and 1 for a complete graph. The density of multigraphs can be higher than 1.
# - **center**<br/>is the set of points with eccentricity equal to radius.
# - **betwnees centrality**<br/>is the number of possible interactions between two non-adjacent points
# - **closeness centrality**<br/>is the average distance of a point from all the others
# - **clustering coefficient**<br/>the measure of the degree to which points in a graph tend to cluster together
# - **degree centrality**<br/>the number of lines incident upon a point
# - **eccentricity** <br/>the eccentricity of a point in a graph is defined as the length of a longest shortest path starting at that point
# - **diameter**<br/>the maximum eccentricity
# - **edge connectivity**<br/>
# is equal to the minimum number of edges that must be removed to disconnect a graph or render it trivial.
# - **node connectivity**<br/>
# is equal to the minimum number of points that must be removed to disconnect a graph or render it trivial.
# - **pagerank**<br/>
# computes a ranking of the nodes (points) in a graph based on the structure of the incoming links (lines). It was originally designed as an algorithm to rank web pages.
# - **periphery** <br/>is the set of nodes with eccentricity equal to the diameter
# - **radius**<br/>is the minimum eccentricity.

# %% [markdown]
# ... and we can plot the map

# %%
fig, ax = ox.plot_graph(G)
plt.show()

# %%
import networkx as nx

# %%
# convert graph to line graph so edges become nodes and vice versa
edge_centrality = nx.closeness_centrality(nx.line_graph(G))
nx.set_edge_attributes(G, edge_centrality, 'edge_centrality')

# %%
# color edges in original graph with closeness centralities from line graph
ec = ox.plot.get_edge_colors_by_attr(G, 'edge_centrality', cmap='inferno')
fig, ax = ox.plot_graph(G, edge_color=ec, edge_linewidth=2, node_size=0)
plt.show()

# %% [markdown]
# # Find the shortest path between 2 points by minimizing travel time

# %% [markdown]
# ## calculate the travel time for each edge

# %% [markdown]
# ### define the origin and destination
# Example:
#
# from the train station of Venezia Santa Lucia to the Rialto Bridge

# %% [markdown]
# **train station**
#
# [Venezia Santa Lucia](https://www.openstreetmap.org/node/6063641885)
#
# lat: 45.4410753<br/>
# lon: 12.3210322
#
#
# **Rialto Bridge**
#
# [Ponte di Rialto](https://www.openstreetmap.org/way/199258374)
#
# lat: 45.43805<br/>
# lon: 12.33593

# %% [markdown]
# ## find the node on the graph nearest on the point given
#
# thes two points are NOT on the graph.
#
# We need to find the nodes nearest

# %%
point_nearest_train_station = ox.distance.nearest_nodes(G,Y=45.4410753,X=12.3210322)
point_nearest_bridge_rialto = ox.distance.nearest_nodes(G,Y=45.43805,X=12.33593)

# %%
# impute missing edge speeds and calculate edge travel times with the speed module
G = ox.speed.add_edge_speeds(G)
G = ox.speed.add_edge_travel_times(G)

# %% [markdown]
# ### calculate the time to walk over each edges

# %%
G = ox.graph_from_place(place_name, network_type='walk')

# %% [markdown]
# plot the walkable street network

# %%
fig, ax = ox.plot_graph(G)
plt.show()

# %%
G = ox.add_edge_speeds(G)
G = ox.add_edge_travel_times(G)

# %% [markdown]
# ... geopandas investigation

# %%
edges = ox.graph_to_gdfs(G,edges=True,nodes=False)

# %%
edges.head(3)
# Out:
#                              osmid bridge             name  highway  oneway  \
# u        v          key
# 27178184 764403528  0    166489461    yes  Ponte di Rialto  footway   False
#          1675825096 0    166489461    yes  Ponte di Rialto  footway   False
#          8670969688 0    450089474    yes  Ponte di Rialto    steps   False
#
#                         reversed  length  speed_kph  travel_time width  \
# u        v          key
# 27178184 764403528  0      False   9.935       41.0          0.9   NaN
#          1675825096 0       True   5.120       41.0          0.4   NaN
#          8670969688 0      False   9.212       41.0          0.8     7
#
#                                                                   geometry  \
# u        v          key
# 27178184 764403528  0    LINESTRING (12.33569 45.43820, 12.33561 45.43813)
#          1675825096 0    LINESTRING (12.33569 45.43820, 12.33573 45.43823)
#          8670969688 0    LINESTRING (12.33569 45.43820, 12.33560 45.43825)
#
#                         tunnel lanes maxspeed est_width access area service  \
# u        v          key
# 27178184 764403528  0      NaN   NaN      NaN       NaN    NaN  NaN     NaN
#          1675825096 0      NaN   NaN      NaN       NaN    NaN  NaN     NaN
#          8670969688 0      NaN   NaN      NaN       NaN    NaN  NaN     NaN
#
#                         junction
# u        v          key
# 27178184 764403528  0        NaN
#          1675825096 0        NaN
#          8670969688 0        NaN

# %%
edges.columns
# Out:
# Index(['osmid', 'bridge', 'name', 'highway', 'oneway', 'reversed', 'length',
#        'speed_kph', 'travel_time', 'width', 'geometry', 'tunnel', 'lanes',
#        'maxspeed', 'est_width', 'access', 'area', 'service', 'junction'],
#       dtype='object')

# %%
edges[edges.travel_time == edges.travel_time.max()].name
# Out:
# u            v            key
# 1927219469   11182286836  0      NaN
# 11182286836  1927219469   0      NaN
# Name: name, dtype: object

# %%
edges[edges.travel_time == edges.travel_time.max()].osmid
# Out:
# u            v            key
# 1927219469   11182286836  0      [404610512, 404610513]
# 11182286836  1927219469   0      [404610512, 404610513]
# Name: osmid, dtype: object

# %% [markdown]
# ![](https://raw.githubusercontent.com/napo/geospatial_course_unitn/master/images/osmid_3400471.jpg)
#
# https://www.openstreetmap.org/way/404610513

# %% [markdown]
# ## find the shortest path between the train station and Rialto bridge

# %%
# find the shortest path between nodes, minimizing travel time, then plot it
route = ox.shortest_path(G, point_nearest_train_station, point_nearest_bridge_rialto, weight="travel_time")

# %%
route
# Out:
# [1927219479,
#  3527986497,
#  2493856508,
#  9055796707,
#  1921651801,
#  27239442,
#  5372700772,
#  4899902714,
#  1855450146,
#  3371984917,
#  2514483400,
#  1858198295,
#  1858198260,
#  3371984290,
#  3371984894,
#  5360645772,
#  1855473678,
#  1855473687,
#  4849873712,
#  4849867342,
#  1856706712,
#  3389313497,
#  5149979474,
#  2732099927,
#  4843929370,
#  2732099913,
#  2732099919,
#  2732099909,
#  2732099904,
#  4803731379,
#  4846061555,
#  1857205293,
#  1857205281,
#  3392463459,
#  1857205288,
#  1856788519,
#  3392463420,
#  3392463416,
#  1857148234,
#  1840378080,
#  2249214723,
#  4803872602,
#  4803871721,
#  1857139330,
#  4902225461,
#  6026202973,
#  1857139318,
#  1857139273,
#  1857139324,
#  1857139332,
#  4983211717,
#  4983211715,
#  5649829357,
#  282975977,
#  4821479726,
#  4977488959,
#  4982153142,
#  4982195156,
#  4982195157,
#  8670969688,
#  27178184,
#  5395065019]

# %% [markdown]
# these values are the ids of each node of the graph

# %%
G.nodes[5395065019]
# Out:
# {'y': 45.4380532, 'x': 12.3359319, 'street_count': 4}

# %%
nodes = ox.graph_to_gdfs(G,edges=False,nodes=True)

# %%
nodes
# Out:
#                      y          x  street_count highway  \
# osmid
# 27178184     45.438197  12.335686             4     NaN
# 27178422     45.432325  12.337206             4     NaN
# 27178423     45.432482  12.337658             3     NaN
# 27178433     45.429240  12.327350             3     NaN
# 27223839     45.434570  12.350321             3     NaN
# ...                ...        ...           ...     ...
# 11090414679  45.434097  12.349435             3     NaN
# 11090414680  45.434147  12.349193             1     NaN
# 11182286836  45.442820  12.315304             3     NaN
# 11202580120  45.431793  12.352420             1     NaN
# 11215309488  45.432654  12.352721             1     NaN
#
#                               geometry
# osmid
# 27178184     POINT (12.33569 45.43820)
# 27178422     POINT (12.33721 45.43233)
# 27178423     POINT (12.33766 45.43248)
# 27178433     POINT (12.32735 45.42924)
# 27223839     POINT (12.35032 45.43457)
# ...                                ...
# 11090414679  POINT (12.34943 45.43410)
# 11090414680  POINT (12.34919 45.43415)
# 11182286836  POINT (12.31530 45.44282)
# 11202580120  POINT (12.35242 45.43179)
# 11215309488  POINT (12.35272 45.43265)
#
# [5278 rows x 5 columns]

# %%
fig, ax = ox.plot_graph_route(G, route, route_linewidth=6, node_size=0, bgcolor='k')
plt.show()

# %%
ox.plot_route_folium(G,route,popup_attribute='name',tiles='CartoDB dark_matter')
#OpenStreetMap
#Stamen Terrain
#Steman Toner
#Stamen Watercolor
#CartoDB positron
#CartoDB dark_matter
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27fb8609c2bbd2712883c0863ec42040 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27fb8609c2bbd2712883c0863ec42040&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27fb8609c2bbd2712883c0863ec42040 = L.map(
#                 &quot;map_27fb8609c2bbd2712883c0863ec42040&quot;,
#                 {
#                     center: [45.43976315139673, 12.328364092105694],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_490fcc0eb82dab37f8b81a6be95d37c3 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/dark_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_27fb8609c2bbd2712883c0863ec42040);
#
#
#             var poly_line_fba7c9d2005f820212a6da90074a54b5 = L.polyline(
#                 [[45.4410566, 12.3210338], [45.4409662, 12.3211934], [45.4409512, 12.3212199]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_27fb8609c2bbd2712883c0863ec42040);
#
#
#         var popup_910ade2da6cc7e2ad939975ed8e70785 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_95d01e05ff42995a5dd935799d09b965 = $(`&lt;div id=&quot;html_95d01e05ff42995a5dd935799d09b965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NaN&lt;/div&gt;`)[0];
#                 popup_910ade2da6cc7e2ad939975ed8e70785.setContent(html_95d01e05ff42995a5dd935799d09b965);
#
#
#
#         poly_line_fba7c9d2005f820212a6da90074a54b5.bindPopup(popup_910ade2da6cc7e2ad939975ed8e70785)
#         ;
#
#
#
#
#             var poly_line_ebd9053f2c42d406248c2448db903a8e = L.polyline(
#                 [[45.4409512, 12.3212199], [45.4409389, 12.3212416], [45.4408913, 12.3213256], [45.4407422, 12.3215889]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_27fb8609c2bbd2712883c0863ec42040);
#
#
#         var popup_bc0d39d32133f534572972fa78b2c8ed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_698915c47cf9ff853c6e0818d2cf03cb = $(`&lt;div id=&quot;html_698915c47cf9ff853c6e0818d2cf03cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;NaN&lt;/div&gt;`)[0];
#                 popup_bc0d39d32133f534572972fa78b2c8ed.setContent(html_698915c47cf9ff853c6e0818d2cf03cb);
#
#
#
#         poly_line_ebd9053f2c42d406248c2448db903a8e.bindPopup(popup_bc0d39d32133f534572972fa78b2c8ed)
#         ;
#
#
#
#
#             var poly_line_bd549d84cb3765f9c239fd3cb918c02e = L.polyline(
#                 [[45.4407422, 12.3215889], [45.4410066, 12.3218645], [45.4410189, 12.3218773]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_27fb8609c2bbd2712883c0863ec42040);
#
#
#         var popup_a0357bdfb3c63b0a0a10082240da056a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9959cfc226c1281398841f31694db6d4 = $(`&lt;div id=&quot;html_9959cfc226c1281398841f31694db6d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&quot;Fondamenta Santa Lucia&quot;&lt;/div&gt;`)[0];
#                 popup_a0357bdfb3c63b0a0a10082240da056a.setContent(html_9959cfc226c12

# %% [markdown]
# how long is our route in meters?

# %%
edge_lengths = ox.utils_graph.get_route_edge_attributes(G, route, 'length')
sum(edge_lengths)
# Out:
# 1613.023

# %% [markdown]
# how many minutes does it take?

# %%
import datetime

# %%
edge_times = ox.utils_graph.get_route_edge_attributes(G, route, 'travel_time')
seconds = sum(edge_times)

# %%
seconds
# Out:
# 141.20000000000007

# %%
str(datetime.timedelta(seconds=seconds))
# Out:
# '0:02:21.200000'

# %% [markdown]
# ## calculate bearing
#
# Calculate the compass bearing from origin node to destination node for each edge in the directed graph then add each bearing as a new edge attribute. Bearing represents angle in degrees (clockwise) between north and the direction from the origin node to the destination node.
# <br/><br/>

# %%
cols = ['city']
names = [('Roma'),('Trento'),('Genova'),('Trieste'),('Venezia')]
cities = gpd.GeoDataFrame(names,columns=cols)
geo_cities = gpd.tools.geocode(cities.city, provider="arcgis")

# %%
cities
# Out:
#       city
# 0     Roma
# 1   Trento
# 2   Genova
# 3  Trieste
# 4  Venezia

# %%
geo_cities
# Out:
#                     geometry  address
# 0  POINT (12.49565 41.90322)     Roma
# 1  POINT (11.11929 46.07005)   Trento
# 2   POINT (8.93917 44.41048)   Genova
# 3  POINT (13.77269 45.65757)  Trieste
# 4  POINT (12.31815 45.43811)  Venezia

# %%
trento = geo_cities[geo_cities.address == 'Trento'].geometry

# %%
trento.geometry.x.values[0]
# Out:
# 11.11929

# %%
roma = geo_cities[geo_cities.address == 'Roma']
genova = geo_cities[geo_cities.address == 'Genova']
trieste = geo_cities[geo_cities.address == 'Trieste']
venezia = geo_cities[geo_cities.address == 'Venezia']

# %% [markdown]
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/2/29/Compass_Card_B%2BW.svg/480px-Compass_Card_B%2BW.svg.png)

# %%
#Trento - Roma
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],roma.geometry.y.values[0],roma.geometry.x.values[0])
# Out:
# 166.14931950629045

# %%
#Trento - Trieste
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],trieste.geometry.y.values[0],trieste.geometry.x.values[0])
# Out:
# 101.62965042130071

# %%
#Trento - Venezia
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],venezia.geometry.y.values[0],venezia.geometry.x.values[0])
# Out:
# 126.63919232581111

# %%
#Trento - Genova
ox.bearing.calculate_bearing(trento.geometry.y.values[0],trento.geometry.x.values[0],genova.geometry.y.values[0],genova.geometry.x.values[0])
# Out:
# 223.54736298562918

# %% [markdown]
# ## Calculate isochornes

# %%
trip_times = [3, 6, 9, 15]  # in minutes
travel_speed = 4  # walking speed in km/hour
from shapely.geometry import Point

# %%
# we select the train station as center
center_node = point_nearest_train_station
center_node = point_nearest_bridge_rialto

# %%
# add an edge attribute for time in minutes required to traverse each edge
meters_per_minute = travel_speed * 1000 / 60  # km per hour to m per minute
for orig,dest, p, data in G_proj.edges(data=True, keys=True):
    data["time"] = data["length"] / meters_per_minute

# %%
# make the isochrone polygons
isochrone_polys = []
for trip_time in sorted(trip_times, reverse=True):
    subgraph = nx.ego_graph(G_proj, center_node, radius=trip_time, distance="time")
    node_points = [Point((data["x"], data["y"])) for node, data in subgraph.nodes(data=True)]
    bounding_poly = gpd.GeoSeries(node_points).unary_union.convex_hull
    isochrone_polys.append(bounding_poly)

# %%
crs_proj = ox.graph_to_gdfs(G_proj)[0].crs

# %%
data = {'trip_time': sorted(trip_times, reverse=True), 'geometry': isochrone_polys}
isochrones = gpd.GeoDataFrame(data,crs=crs_proj)

# %%
isochrones.explore(column='trip_time',cmap='Reds')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fb212392e890f53653ce615fa8334a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fb212392e890f53653ce615fa8334a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fb212392e890f53653ce615fa8334a5 = L.map(
#                 &quot;map_5fb212392e890f53653ce615fa8334a5&quot;,
#                 {
#                     center: [45.438096099999996, 12.33615835],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5fb212392e890f53653ce615fa8334a5);
#
#
#
#
#
#             var tile_layer_23f1f5feae482badee40e0f1fc02e037 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5fb212392e890f53653ce615fa8334a5);
#
#
#             map_5fb212392e890f53653ce615fa8334a5.fitBounds(
#                 [[45.43179719999999, 12.3263568], [45.444395, 12.3459599]],
#                 {}
#             );
#
#
#         function geo_json_c9efbc2b835252195b65ee895843d3b3_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#67000d&quot;, &quot;fillColor&quot;: &quot;#67000d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#fb6b4b&quot;, &quot;fillColor&quot;: &quot;#fb6b4b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#fcbca2&quot;, &quot;fillColor&quot;: &quot;#fcbca2&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#fff5f0&quot;, &quot;fillColor&quot;: &quot;#fff5f0&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c9efbc2b835252195b65ee895843d3b3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c9efbc2b835252195b65ee895843d3b3_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_c9efbc2b835252195b65ee895843d3b3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c9efbc2b835252195b65ee895843d3b3_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_c9efbc2b835252195b65ee895843d3b3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c9efbc2b835252195b65ee895843d3b3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c9efbc2b835252195b65ee895843d3b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_c9efbc2b835252195b65ee895843d3b3_onEachFeature,
#
#                 style: geo_json_c9efbc2b835252195b65ee895843d3b3_styler,
#                 pointToLayer: geo_json_c9efbc2b835252195b65ee895843d3b3_pointToLayer
#         });
#
#         function geo_json_c9efbc2b835252195b65ee895843d3b3_add (data) {
#             geo_json_c9efbc2b835252195b65ee895843d3b3
#                 .addData(data)

# %% [markdown]
# ---
#
# # Use GraphHoper
#
# ![](https://www.graphhopper.com/wp-content/uploads/2018/03/graphhopper-logo-small.png)
#
# Visit [https://www.graphhopper.com/](https://www.graphhopper.com/)
#
# ## Install a local instance
# - download data from OpenStreetMap<br/>Example: Trento<br/><br/>[https://osmit-estratti.wmcloud.org/dati/poly/comuni/pbf/022205_Trento.osm.pbf](https://osmit-estratti.wmcloud.org/dati/poly/comuni/pbf/022205_Trento.osm.pbf)
# - check to have istallend java SE version 17. <pre>java --version
# java 17.0.1 2021-10-19 LTS
# Java(TM) SE Runtime Environment (build 17.0.1+12-LTS-39)
# Java HotSpot(TM) 64-Bit Server VM (build 17.0.1+12-LTS-39, mixed mode, sharing)
# </pre>
# - download the jar of grapphoper from github - [https://repo1.maven.org/maven2/com/graphhopper/graphhopper-web/7.0/graphhopper-web-7.0.jar](https://repo1.maven.org/maven2/com/graphhopper/graphhopper-web/7.0/graphhopper-web-7.0.jar)
# - create the yaml file configuration for the graphhopper with the variabile <pre>datareader.file</pre> equals to the file name you donwloaded (eg."022205_Trento.osm.pbf") and the configuration with the different profiles (eg. car, bike, foot ...).<br/>An example [here](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/data/conf_grapphoper/config_trento.yml)
# - run the grapphoper istance<br/><pre>java -jar graphhopper*.jar server config_trento.yml</pre>
# - you can reach the service at <pre>http://localhost:8989</pre>
#
# Here a bash script to download everything<br/>
# tip: create a working directory
#
# ```bash
# wget https://osmit-estratti.wmcloud.org/dati/poly/comuni/pbf/022205_Trento.osm.pbf
# wget https://repo1.maven.org/maven2/com/graphhopper/graphhopper-web/7.0/graphhopper-web-7.0.jar
# wget https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/data/conf_grapphoper/config_trento.yml
# ```
#
#
# later run the service and ... have patience for the first run because graphhopper needs to parse the pbf file gave in input
#
#
# ```bash
# java -jar graphhopper*.jar server config_trento.yml
# ```
#
# You can use the bash script [here](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/code/utils/graphhopper_start.sh)
#
# The base URL now is: <pre>http://localhost:8989</pre>
#
# Otherwise you can use the official instance with a token api and relative [prices](https://www.graphhopper.com/pricing/)
#
# Here a list of the more important API available
#
# | end point | function | description |
# |---|---|---|
# |http://localhost:8989/| maps | web client front-end for routing |
# |http://localhost:8989/health| health | inform if the service is running |
# |http://localhost:8989/isochrone| isochrone | calculate the isochrone [here](https://docs.graphhopper.com/#tag/Isochrone-API) the documentation |
# |http://localhost:8989/match| match | map matching service in POST - [here](https://docs.graphhopper.com/#tag/Map-Matching-API) the documentation |
# |http://localhost:8989/route| routing service | documentation [here](https://docs.graphhopper.com/#tag/Routing-API)|

# %% [markdown]
# ## How to use it
# ### routing
#
# Calculate the routing from [Sanbapolis](https://www.openstreetmap.org/?mlat=46.04717&mlon=11.13261#map=18/46.04717/11.13261) to [BUC](https://www.openstreetmap.org/?mlat=46.05968&mlon=11.11552#map=19/46.05968/11.11552)
#
# Sanbapolis:
# - latitude: 46.04717
# - longitude: 11.13261
#
# BUC:
# - latitude: 46.05968
# - longitude: 11.11552
#
# Syntax in GET:
# ```
# http://localhost:8989/route?point=latitude,longitude&point=latitude,longitude
# ```

# %%
import requests

url = "http://localhost:8989/route"
start_latitude = "46.04717"
start_longitude = "11.13261"
start_point = start_latitude + "," + start_longitude
end_latitude = "46.05968"
end_longitude = "11.11552"
end_point = end_latitude + "," + end_longitude

query = "?profile=car"
query += "&locale=it"
query += "&point=" +start_point
query += "&point=" +end_point

response = requests.get(url+query) 

data = response.json()
print(data.keys())
# Out:
# dict_keys(['hints', 'info', 'paths'])

# %%
data['hints']
# Out:
# {'visited_nodes.sum': 54, 'visited_nodes.average': 54.0}

# %%
data['info']
# Out:
# {'copyrights': ['GraphHopper', 'OpenStreetMap contributors'], 'took': 24}

# %%
len(data['paths'])
# Out:
# 1

# %%
data['paths'][0].keys()
# Out:
# dict_keys(['distance', 'weight', 'time', 'transfers', 'points_encoded', 'bbox', 'points', 'instructions', 'legs', 'details', 'ascend', 'descend', 'snapped_waypoints'])

# %%
data['paths'][0]['distance'] #meters
# Out:
# 2898.391

# %%
data['paths'][0]['time'] #milliseconds
# Out:
# 270285

# %%
data['paths'][0]['points']
# Out:
# 'wq`xGyi}bAFF\\FhHIPJDVFpEQ^qA@cBTSHuQm@u@Hi@`@OOK?MJER@JM@qDtBa@RqAb@iAZ{AN}EBkEt@c@NcAj@qSnIqBbC}BdCeGhGr@pFfD`Z?RERMBGP?NBL?bDHpBP`CJlD`@F'

# %% [markdown]
# We need the polyne encoder/decoder
#
# Check here the [documentation](https://developers.google.com/maps/documentation/utilities/polylinealgorithm)

# %%
try:
    import polyline 
except ModuleNotFoundError as e:
    # !pip install -U polyline==2.0.1 --break-system-packages
    import polyline

# %%
points = polyline.decode(data['paths'][0]['points'] )

# %%
from shapely.geometry import LineString
from shapely.ops import transform
route = LineString(points)

# %%
route
# Out:
# <LINESTRING (46.047 11.133, 46.047 11.133, 46.047 11.133, 46.045 11.133, 46....>

# %%
route = transform(lambda x, y: (y, x),route)

# %%
route
# Out:
# <LINESTRING (11.133 46.047, 11.133 46.047, 11.133 46.047, 11.133 46.045, 11....>

# %%
routing_result = gpd.GeoDataFrame(
    [{"time": data['paths'][0]['time'],"geometry": route, "distance":data['paths'][0]['distance']}],
    crs="epsg:4326",
    geometry="geometry")

# %%
routing_result.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bcefbf46f189a301777c0b6abc18523 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bcefbf46f189a301777c0b6abc18523&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bcefbf46f189a301777c0b6abc18523 = L.map(
#                 &quot;map_6bcefbf46f189a301777c0b6abc18523&quot;,
#                 {
#                     center: [46.053129999999996, 11.12426],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_6bcefbf46f189a301777c0b6abc18523);
#
#
#
#
#
#             var tile_layer_8191e12284983a17154f300afe749fcd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6bcefbf46f189a301777c0b6abc18523);
#
#
#             map_6bcefbf46f189a301777c0b6abc18523.fitBounds(
#                 [[46.04532, 11.11591], [46.06094, 11.13261]],
#                 {}
#             );
#
#
#         function geo_json_fdf178301b28b4cda38e731a97ea84da_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_fdf178301b28b4cda38e731a97ea84da_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_fdf178301b28b4cda38e731a97ea84da_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_fdf178301b28b4cda38e731a97ea84da_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_fdf178301b28b4cda38e731a97ea84da_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_fdf178301b28b4cda38e731a97ea84da.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_fdf178301b28b4cda38e731a97ea84da_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_fdf178301b28b4cda38e731a97ea84da = L.geoJson(null, {
#                 onEachFeature: geo_json_fdf178301b28b4cda38e731a97ea84da_onEachFeature,
#
#                 style: geo_json_fdf178301b28b4cda38e731a97ea84da_styler,
#                 pointToLayer: geo_json_fdf178301b28b4cda38e731a97ea84da_pointToLayer
#         });
#
#         function geo_json_fdf178301b28b4cda38e731a97ea84da_add (data) {
#             geo_json_fdf178301b28b4cda38e731a97ea84da
#                 .addData(data)
#                 .addTo(map_6bcefbf46f189a301777c0b6abc18523);
#         }
#             geo_json_fdf178301b28b4cda38e731a97ea84da_add({&quot;bbox&quot;: [11.11591, 46.04532, 11.13261, 46.06094], &quot;features&quot;: [{&quot;bbox&quot;: [11.11591, 46.04532, 11.13261, 46.06094], &quot;geometry&quot;: {&quot;coordinates&quot;: [[11.13261, 46.04716], [11.13257, 46.04712], [11.13253, 46.04697], [11.13258, 46.04548], [11.13252, 46.04539], [11.1324, 46.04536], [11.13135, 46.04532], [11.13119, 46.04541], [11.13118, 46.04582], [11.13107, 46.04632], [11.13102, 46.04642], [11.13125, 46.04941], [11.1312, 46.04968], [11.13103, 46.04989], [11.13111, 46.04997], [11.13111, 46.05003], [11.13105, 46.0501], [11.13095, 46.05013], [11.13089, 46.05012], [11.13088, 46.05019], [11.13029, 46.05108], [11.13019, 46.05125], [11.13001, 4

# %% [markdown]
# #### and by foot

# %%
query = "?profile=foot"
query += "&locale=it"
query += "&point=" +start_point
query += "&point=" +end_point
query += "&ch.disable=true" 
response = requests.get(url+query) 
data = response.json()
points = polyline.decode(data['paths'][0]['points'])
route = transform(lambda x, y: (y, x),LineString(points))
routing_result = gpd.GeoDataFrame(
    [{"time": data['paths'][0]['time'],"geometry": route, "distance":data['paths'][0]['distance']}],
    crs="epsg:4326",
    geometry="geometry")
routing_result.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5511b224bb85f61c0bbb48acfcb901cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5511b224bb85f61c0bbb48acfcb901cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5511b224bb85f61c0bbb48acfcb901cd = L.map(
#                 &quot;map_5511b224bb85f61c0bbb48acfcb901cd&quot;,
#                 {
#                     center: [46.05403, 11.12407],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5511b224bb85f61c0bbb48acfcb901cd);
#
#
#
#
#
#             var tile_layer_6af58627503029f2f719f011b6d4d49c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5511b224bb85f61c0bbb48acfcb901cd);
#
#
#             map_5511b224bb85f61c0bbb48acfcb901cd.fitBounds(
#                 [[46.04716, 11.11552], [46.0609, 11.13262]],
#                 {}
#             );
#
#
#         function geo_json_07b2aefa1b2e535b27b5b8ced5983e89_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_07b2aefa1b2e535b27b5b8ced5983e89_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_07b2aefa1b2e535b27b5b8ced5983e89_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_07b2aefa1b2e535b27b5b8ced5983e89_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_07b2aefa1b2e535b27b5b8ced5983e89_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_07b2aefa1b2e535b27b5b8ced5983e89.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_07b2aefa1b2e535b27b5b8ced5983e89_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_07b2aefa1b2e535b27b5b8ced5983e89 = L.geoJson(null, {
#                 onEachFeature: geo_json_07b2aefa1b2e535b27b5b8ced5983e89_onEachFeature,
#
#                 style: geo_json_07b2aefa1b2e535b27b5b8ced5983e89_styler,
#                 pointToLayer: geo_json_07b2aefa1b2e535b27b5b8ced5983e89_pointToLayer
#         });
#
#         function geo_json_07b2aefa1b2e535b27b5b8ced5983e89_add (data) {
#             geo_json_07b2aefa1b2e535b27b5b8ced5983e89
#                 .addData(data)
#                 .addTo(map_5511b224bb85f61c0bbb48acfcb901cd);
#         }
#             geo_json_07b2aefa1b2e535b27b5b8ced5983e89_add({&quot;bbox&quot;: [11.11552, 46.04716, 11.13262, 46.0609], &quot;features&quot;: [{&quot;bbox&quot;: [11.11552, 46.04716, 11.13262, 46.0609], &quot;geometry&quot;: {&quot;coordinates&quot;: [[11.13261, 46.04716], [11.13262, 46.04718], [11.13252, 46.04729], [11.13229, 46.04764], [11.13213, 46.04794], [11.13201, 46.04805], [11.13181, 46.04814], [11.13166, 46.04824], [11.13158, 46.04835], [11.13145, 46.04864], [11.13128, 46.0488], [11.13121, 46.04882], [11.13125, 46.04941], [11.13124, 46.04956], [11.1312, 46.04968], [11.13103, 46.04989], [11.13111, 46.04997], [11.13111, 46.05003], [11.13105, 46.0501], [11.13095, 46.05013], [11.13089, 46.05012], [11.13088, 46.05019], [11.13029, 46.05108], [11

# %% [markdown]
# ### ischrone
#
# Calculate a isochrone of 5 minutes of [Sanbapolis](https://www.openstreetmap.org/?mlat=46.04717&mlon=11.13261#map=18/46.04717/11.13261)
#
# Sanbapolis:
# - latitude: 46.04717
# - longitude: 11.13261
# Syntax in GET:
# ```
# http://localhost:8989/isochrone?point=latitude,longitude&time_limit=timeseconds&distance_limit=distance&profile=foot&bucket=1&reverse_flow=false
# ```

# %%
url = "http://localhost:8989/isochrone"
lat = "46.04717"
lon = "11.13261"
minutes_distance = 5
timeseconds = str(minutes_distance*60)
p = lon + "," + lat
query = {
  "point": lat + "," + lon,
  "time_limit": timeseconds,
  "distance_limit": "0",
  "profile": "foot",
  "buckets": "1",
  "reverse_flow": "false"}
response = requests.get(url, params=query)
data = response.json()

# %%
from shapely.geometry import Polygon
geometry = Polygon(data['polygons'][0]['geometry']['coordinates'][0])

# %%
isochrone = gpd.GeoDataFrame(
    [{"minutes_distance":minutes_distance,"geometry": geometry}],
    crs="epsg:4326",
    geometry="geometry")

# %%
isochrone.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77db360303ee7533798ac4c154e72e9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77db360303ee7533798ac4c154e72e9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77db360303ee7533798ac4c154e72e9b = L.map(
#                 &quot;map_77db360303ee7533798ac4c154e72e9b&quot;,
#                 {
#                     center: [46.04700805, 11.13300555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_77db360303ee7533798ac4c154e72e9b);
#
#
#
#
#
#             var tile_layer_8ccd253c3ac7724d24865e99fc650fe3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77db360303ee7533798ac4c154e72e9b);
#
#
#             map_77db360303ee7533798ac4c154e72e9b.fitBounds(
#                 [[46.043404249999995, 11.130199099999999], [46.05061185, 11.135812000000001]],
#                 {}
#             );
#
#
#         function geo_json_d531e2eaa289ca6a713ae5063979e212_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_d531e2eaa289ca6a713ae5063979e212_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_d531e2eaa289ca6a713ae5063979e212_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_d531e2eaa289ca6a713ae5063979e212_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_d531e2eaa289ca6a713ae5063979e212_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_d531e2eaa289ca6a713ae5063979e212.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_d531e2eaa289ca6a713ae5063979e212_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_d531e2eaa289ca6a713ae5063979e212 = L.geoJson(null, {
#                 onEachFeature: geo_json_d531e2eaa289ca6a713ae5063979e212_onEachFeature,
#
#                 style: geo_json_d531e2eaa289ca6a713ae5063979e212_styler,
#                 pointToLayer: geo_json_d531e2eaa289ca6a713ae5063979e212_pointToLayer
#         });
#
#         function geo_json_d531e2eaa289ca6a713ae5063979e212_add (data) {
#             geo_json_d531e2eaa289ca6a713ae5063979e212
#                 .addData(data)
#                 .addTo(map_77db360303ee7533798ac4c154e72e9b);
#         }
#             geo_json_d531e2eaa289ca6a713ae5063979e212_add({&quot;bbox&quot;: [11.130199099999999, 46.043404249999995, 11.135812000000001, 46.05061185], &quot;features&quot;: [{&quot;bbox&quot;: [11.130199099999999, 46.043404249999995, 11.135812000000001, 46.05061185], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.13311655, 46.04852305], [11.1325471, 46.048736149999996], [11.132496549999999, 46.0487387], [11.13231185, 46.0487781], [11.1318617, 46.0492263], [11.13150085, 46.04956175], [11.13149645, 46.04965845], [11.131435549999999, 46.049714050000006], [11.131474350000001, 46.0498728], [11.13152505, 46.0499031], [11.131591499999999, 46.0499075], [11.13163755, 46.04991055], [11.131892, 46.050094349999

# %% [markdown]
# ### Istodistance
# ... and in 300 meters

# %%
distance = 300
p = lon + "," + lat
query = {
  "point": lat + "," + lon,
  "time_limit": 0,
  "distance_limit":distance,
  "profile": "foot",
  "buckets": "1",
  "reverse_flow": "false"}
response = requests.get(url, params=query)
data = response.json()

# %%
geometry = Polygon(data['polygons'][0]['geometry']['coordinates'][0])
isodistance = gpd.GeoDataFrame(
    [{"minutes_distance":minutes_distance,"geometry": geometry}],
    crs="epsg:4326",
    geometry="geometry")
isodistance.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a08ab5c4943df4d007fff82a88995ff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a08ab5c4943df4d007fff82a88995ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a08ab5c4943df4d007fff82a88995ff = L.map(
#                 &quot;map_4a08ab5c4943df4d007fff82a88995ff&quot;,
#                 {
#                     center: [46.047152, 11.13328455],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4a08ab5c4943df4d007fff82a88995ff);
#
#
#
#
#
#             var tile_layer_7ef4162bd0450b6e8f862fe02277f7af = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a08ab5c4943df4d007fff82a88995ff);
#
#
#             map_4a08ab5c4943df4d007fff82a88995ff.fitBounds(
#                 [[46.0445206, 11.1307571], [46.0497834, 11.135812000000001]],
#                 {}
#             );
#
#
#         function geo_json_7b977201862652155cb68a04d9a3b243_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_7b977201862652155cb68a04d9a3b243_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_7b977201862652155cb68a04d9a3b243_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_7b977201862652155cb68a04d9a3b243_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_7b977201862652155cb68a04d9a3b243_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_7b977201862652155cb68a04d9a3b243.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_7b977201862652155cb68a04d9a3b243_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_7b977201862652155cb68a04d9a3b243 = L.geoJson(null, {
#                 onEachFeature: geo_json_7b977201862652155cb68a04d9a3b243_onEachFeature,
#
#                 style: geo_json_7b977201862652155cb68a04d9a3b243_styler,
#                 pointToLayer: geo_json_7b977201862652155cb68a04d9a3b243_pointToLayer
#         });
#
#         function geo_json_7b977201862652155cb68a04d9a3b243_add (data) {
#             geo_json_7b977201862652155cb68a04d9a3b243
#                 .addData(data)
#                 .addTo(map_4a08ab5c4943df4d007fff82a88995ff);
#         }
#             geo_json_7b977201862652155cb68a04d9a3b243_add({&quot;bbox&quot;: [11.1307571, 46.0445206, 11.135812000000001, 46.0497834], &quot;features&quot;: [{&quot;bbox&quot;: [11.1307571, 46.0445206, 11.135812000000001, 46.0497834], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[11.13194275, 46.04772745], [11.13210855, 46.047789449999996], [11.132187349999999, 46.047643449999995], [11.132135550000001, 46.0475105], [11.13222815, 46.047324700000004], [11.13233275, 46.04717805], [11.132334499999999, 46.04702615], [11.132256850000001, 46.04679025], [11.13226855, 46.0465107], [11.1322786, 46.04609415], [11.13229125, 46.0457357], [11.132291850000001, 46.04571765], [11.1321537, 46.04559545], [11.1320374, 46.0454453], [11.13182

# %% [markdown]
# ## Map Matching
#
# ![](https://fmm-wiki.github.io/assets/images/demo2.gif)
#
# Read the documentation of [Fast Map Matching](https://fmm-wiki.github.io/)

# %% [markdown]
# An example
#
# ![](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/images/journey_trento_downtown.png)
#
# [Download](https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/data/journey_trento_downtown.gpx)
#
# http://localhost:8989/maps/map-matching/

# %%
import requests
headers = {
    'content-type': 'application/gpx+xml',
}
gpx_url = "https://raw.githubusercontent.com/napo/geospatial_datascience_unitn_2023/main/data/journey_trento_downtown.gpx"
response = requests.get(gpx_url)
gpx_str = response.content
url = 'http://localhost:8989/match'
params = {
    'profile': 'foot',
    'gps_accuracy': '10',
    'type': 'json'
}
response = requests.post(url, headers=headers, params=params, data=gpx_str,verify=False)
data = response.json()

# %%
data.keys()
# Out:
# dict_keys(['hints', 'info', 'paths', 'map_matching'])

# %%
data['map_matching']
# Out:
# {'original_distance': 1342.374625154211,
#  'distance': 1370.7233911462508,
#  'time': 986924}

# %%
len(data['paths'])
# Out:
# 1

# %%
data['paths'][0].keys()
# Out:
# dict_keys(['distance', 'weight', 'time', 'transfers', 'points_encoded', 'bbox', 'points', 'instructions', 'legs', 'details', 'ascend', 'descend', 'snapped_waypoints'])

# %%
points = polyline.decode(data['paths'][0]['points'] )

# %%
route = LineString(points)
route = transform(lambda x, y: (y, x),route)
routing_result = gpd.GeoDataFrame(
    [{"time": data['paths'][0]['time'],"geometry": route, "distance":data['paths'][0]['distance']}],
    crs="epsg:4326",
    geometry="geometry")
routing_result.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dce47be0a184081722abadf509aa83a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dce47be0a184081722abadf509aa83a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dce47be0a184081722abadf509aa83a8 = L.map(
#                 &quot;map_dce47be0a184081722abadf509aa83a8&quot;,
#                 {
#                     center: [46.06757, 11.123835],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_dce47be0a184081722abadf509aa83a8);
#
#
#
#
#
#             var tile_layer_081e6783baeb23bd9890c58436200c12 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dce47be0a184081722abadf509aa83a8);
#
#
#             map_dce47be0a184081722abadf509aa83a8.fitBounds(
#                 [[46.06519, 11.11955], [46.06995, 11.12812]],
#                 {}
#             );
#
#
#         function geo_json_5f93b86144c5f6e20a580a670583595e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5f93b86144c5f6e20a580a670583595e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5f93b86144c5f6e20a580a670583595e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5f93b86144c5f6e20a580a670583595e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5f93b86144c5f6e20a580a670583595e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_5f93b86144c5f6e20a580a670583595e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5f93b86144c5f6e20a580a670583595e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5f93b86144c5f6e20a580a670583595e = L.geoJson(null, {
#                 onEachFeature: geo_json_5f93b86144c5f6e20a580a670583595e_onEachFeature,
#
#                 style: geo_json_5f93b86144c5f6e20a580a670583595e_styler,
#                 pointToLayer: geo_json_5f93b86144c5f6e20a580a670583595e_pointToLayer
#         });
#
#         function geo_json_5f93b86144c5f6e20a580a670583595e_add (data) {
#             geo_json_5f93b86144c5f6e20a580a670583595e
#                 .addData(data)
#                 .addTo(map_dce47be0a184081722abadf509aa83a8);
#         }
#             geo_json_5f93b86144c5f6e20a580a670583595e_add({&quot;bbox&quot;: [11.11955, 46.06519, 11.12812, 46.06995], &quot;features&quot;: [{&quot;bbox&quot;: [11.11955, 46.06519, 11.12812, 46.06995], &quot;geometry&quot;: {&quot;coordinates&quot;: [[11.11955, 46.0667], [11.12019, 46.06677], [11.12035, 46.06603], [11.12103, 46.06609], [11.12104, 46.06604], [11.12109, 46.06604], [11.1211, 46.06556], [11.12122, 46.06553], [11.12121, 46.06546], [11.12289, 46.06519], [11.12315, 46.06524], [11.12305, 46.06552], [11.12269, 46.06624], [11.12259, 46.06627], [11.1224, 46.06651], [11.12229, 46.06677], [11.12331, 46.06691], [11.12329, 46.06696], [11.12319, 46.06727], [11.12325, 46.06728], [11.12325, 46.06731], [11.12375, 46.06734], [11.12377, 46.06735],

# %% [markdown]
# ---
#
# # GNSS
#
#  Global Navigation Satellite System (GNSS) refers to a constellation of satellites providing signals from space that transmit positioning and timing data to GNSS receivers. The receivers then use this data to determine location. By definition, GNSS provides global coverage.
#
# ## basic
# ![](https://ardupilot.org/copter/_images/ag_GPS_Operation_New_low_res.jpg)
#
# ## with corrections
# ![](https://freesvg.org/img/GPS_differentialCorrection.png)
#
# ---

# %% [markdown]
# # GPX Format
# GPX, or GPS Exchange Format, is an XML schema designed as a common GPS data format for software applications. It can be used to describe waypoints, tracks, and routes.
#
# ## units
# ### position
# latitude and longitude are expressed in **decimal degrees**, and **elevation in meters**, both using the **WGS 84 datum** (epsg 4326).
# ### time
# dates and times are not local time, but instead are Coordinated Universal Time (UTC) using ISO 8601 format (YYYY-MM-DDTHH:MM:SSZ)
#
#
# ## data
#
# ![](https://upload.wikimedia.org/wikipedia/commons/a/a2/Wayroutrackp.png)
#
# (image by [Berklas](https://commons.wikimedia.org/w/index.php?title=User:Berklas) distributed under cc-by-sa 3.0)
#
# - **wptType** is an individual waypoint among a collection of points with no sequential relationship. It consists of the WGS 84 (GPS) coordinates of a point and possibly other descriptive information.
# - **rteType** is a route, an ordered list of routepoint (waypoints representing a series of significant turn or stage points) leading to a destination.
# - **trkType** is a track, made of at least one segment containing waypoints, that is, an ordered list of points describing a path. A Track Segment holds a list of Track Points which are logically connected in order. To represent a single GPS track where GPS reception was lost, or the GPS receiver was turned off, start a new Track Segment for each continuous span of track data.
#
#
# details about the format on fhe officiale [website](https://www.topografix.com/gpx.asp)
#
#
# ```xml
# <?xml version="1.0" encoding="UTF-8" standalone="no" ?>
# <gpx xmlns="http://www.topografix.com/GPX/1/1" xmlns:gpxx="http://www.garmin.com/xmlschemas/GpxExtensions/v3" xmlns:gpxtpx="http://www.garmin.com/xmlschemas/TrackPointExtension/v1" creator="Oregon 400t" version="1.1" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xsi:schemaLocation="http://www.topografix.com/GPX/1/1 http://www.topografix.com/GPX/1/1/gpx.xsd http://www.garmin.com/xmlschemas/GpxExtensions/v3 http://www.garmin.com/xmlschemas/GpxExtensionsv3.xsd http://www.garmin.com/xmlschemas/TrackPointExtension/v1 http://www.garmin.com/xmlschemas/TrackPointExtensionv1.xsd">
#   <metadata>
#     <link href="http://www.garmin.com">
#       <text>Garmin International</text>
#     </link>
#     <time>2009-10-17T22:58:43Z</time>
#   </metadata>
#   <trk>
#     <name>Example GPX Document</name>
#     <trkseg>
#       <trkpt lat="47.644548" lon="-122.326897">
#         <ele>4.46</ele>
#         <time>2009-10-17T18:37:26Z</time>
#       </trkpt>
#       <trkpt lat="47.644548" lon="-122.326897">
#         <ele>4.94</ele>
#         <time>2009-10-17T18:37:31Z</time>
#       </trkpt>
#       <trkpt lat="47.644548" lon="-122.326897">
#         <ele>6.87</ele>
#         <time>2009-10-17T18:37:34Z</time>
#       </trkpt>
#     </trkseg>
#   </trk>
# </gpx>
# ```
#
# information from [wikipedia](https://en.wikipedia.org/wiki/GPS_Exchange_Format)

# %% [markdown]
# ---
#
# # Commmon problems
#
# Missing Data
# - Temporal gaps
# - Spatial gaps
#
# Incorrect data:
# - location or time is incorrect in the data frame
#
# Outliers:
# - Too fast movements
# - Incorrect order of temporal information
#
#
# ## A funny story
#
# Channon Perry and her boyfriend [analysed](https://chan.co.za/how-fateful) their personal GPS traces to find ‘missed potential fateful encounters’ in the past.
#
#
# ---

# %% [markdown]
# ## Playing with GPX

# %%
try:
  import gpxpy
except ModuleNotFoundError as e:
  # !pip install gpxpy==1.5.0
  import gpxpy

if gpxpy.__version__ != "1.5.0":
  # !pip install -U gpxpy==1.5.0

# %%
import gpxpy
import urllib.request
from datetime import datetime,timedelta

import matplotlib.pyplot as plt
from shapely.geometry import Point
import warnings
warnings.filterwarnings('ignore') # ignore warnings

# %%
try:
  import hvplot 
except ModuleNotFoundError as e:
  # !pip install hvplot==0.8.4
  import hvplot

if hvplot.__version__ != "0.8.4":
  # !pip install -U hvplot==0.8.4

try:
  import geoviews 
except ModuleNotFoundError as e:
  # !pip install geoviews==1.10.1
  import geoviews

if geoviews.__version__ != "1.10.1":
  # !pip install -U geoviews==1.10.1

# %%
try:
  import movingpandas as mpd
except ModuleNotFoundError as e:
  # !pip install movingpandas==0.17.1
  import movingpandas as mpd

if mpd.__version__ != "0.17.1":
  # !pip install -U movingpandas==0.17.11

# %% [markdown]
# ## Download the data
#
#
# ![](https://github.com/napo/geospatial_course_unitn/blob/master/images/strava_clean.jpg?raw=true)
#
# If you are registered and the author permits the download you can download the gps track but and investigate with [GPX Studio](https://gpx.studio) **without timestamps**
#
#
# ![gpx-strava.png](https://i.postimg.cc/x8mMQL9C/gpx-strava.png)]
#
# [download file](https://gist.github.com/napo/2aa15957b687dd676d448888619bd39f)
#
# or ... you can use [Strava To Gpx](https://mapstogpx.com/strava/)
#
#
# ![gpx-full.png](https://i.postimg.cc/yNrLYXCX/gpx-full.png)]
#
# [download file](https://gist.github.com/napo/4d0c14585da0ef96f263faa0e8d97ff5)

# %%
gpx_url = "https://gist.githubusercontent.com/napo/4d0c14585da0ef96f263faa0e8d97ff5/raw/efba18f806459b462a1e485023cdd01c4d20e01a/strava_full.gpx"
gpx_file = "strava_full.gpx"
urllib.request.urlretrieve(gpx_url,gpx_file)
gpx_file = open(gpx_file, 'r')
gpx = gpxpy.parse(gpx_file)

# %%
gpx.creator
# Out:
# 'https://www.mapstogpx.com/strava'

# %%
len(gpx.tracks)
# Out:
# 1

# %%
len(gpx.tracks[0].segments)
# Out:
# 1

# %%
segment = gpx.tracks[0].segments[0]

# %%
segment
# Out:
# GPXTrackSegment(points=[...])

# %%
type(segment.points)
# Out:
# list

# %%
segment.points[0].latitude
# Out:
# 45.900222

# %%
segment.points[0].longitude
# Out:
# 10.847826

# %%
segment.points[0].elevation
# Out:
# 96.5

# %% [markdown]
# ## creation of a pandas DataFrame

# %%
import movingpandas as mpd
import pandas as pd
data = []
for point_idx, point in enumerate(segment.points):
    data.append([point.longitude, point.latitude,
                point.elevation, point.time]) 

columns = ['longitude', 'latitude', 'altitude', 'time'] 
gpx_tracks = pd.DataFrame(data, columns=columns)
# Strava to GPX assign the date of the download of the file as timestamp and SimpleTZ("Z") as TimeZone.
# we can remove it
gpx_tracks['time'] = gpx_tracks['time'].apply(lambda x: x.replace(tzinfo=None))

# index creation needed by MovingPandas
df = gpx_tracks.set_index('time')

# %%
start_point = data[0]
end_point = data[-1]
# travel time
# steps to calcolate the difference of time from the timestamp in the first point to the last.
travel_time = end_point[3]-start_point[3]
travel_time_seconds = timedelta(seconds=travel_time.total_seconds())
travel_time_hours = str(timedelta(seconds=travel_time_seconds.seconds))
print_travel_time = travel_time_hours.split(':')
print("travel time %sh %s' %s''" % (print_travel_time[0], print_travel_time[1], print_travel_time[2]))
# Out:
# travel time 2h 34' 41''

# %% [markdown]
# ## reverse geocoding

# %%
from geopy.geocoders import Nominatim 

latlon = str(start_point[1]) + "," + str(start_point[0])
geolocator = Nominatim(user_agent="geospatial course unitn")
starting_place = geolocator.reverse(latlon)

# %%
starting_place
# Out:
# Location(28/C, Via Luigi Pigarelli, Pasina, Varone, Riva del Garda, Comunità Alto Garda e Ledro, Provincia di Trento, Trentino-Alto Adige/Südtirol, 38066, Italia, (45.8999431, 10.8472436, 0.0))

# %%
latlon = str(end_point[1]) + "," + str(end_point[0])
geolocator = Nominatim(user_agent="geospatial course unitn")
arrival_place = geolocator.reverse(latlon)

# %%
arrival_place
# Out:
# Location(Ospedale di Arco, 48, Viale dei Capitelli, Chiarano, Arco, Comunità Alto Garda e Ledro, Provincia di Trento, Trentino-Alto Adige/Südtirol, 38062, Italia, (45.919666250000006, 10.875398703679842, 0.0))

# %% [markdown]
# ##  Analyzing trajectories

# %%
# GeoDataFrame for MovingPandas
geo_df = gpd.GeoDataFrame(df, 
crs=4326,
geometry= gpd.points_from_xy(df.longitude, df.latitude, df.altitude))

# %%
geo_df.plot()
plt.show()

# %%
trajectory = mpd.Trajectory(geo_df, 0)

# %%
trajectory
# Out:
# Trajectory 0 (2021-10-12 12:01:38 to 2021-10-12 14:36:19) | Size: 5532 | Length: 40316.6m
# Bounds: (10.731099, 45.861882, 10.875513, 45.919142)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836

# %%
# object trajectory from MovingPandas
trajectory = mpd.Trajectory(geo_df, 1)

# %%
trajectory.plot()
plt.show()

# %%
trajectory.add_speed(overwrite=True)
trajectory.df
# Out:
#                      longitude   latitude  altitude  \
# time
# 2021-10-12 12:01:38  10.847826  45.900222      96.5
# 2021-10-12 12:01:39  10.847850  45.900264      96.5
# 2021-10-12 12:01:40  10.847843  45.900125      96.5
# 2021-10-12 12:01:41  10.847836  45.899890      96.5
# 2021-10-12 12:01:42  10.847835  45.899786      96.5
# ...                        ...        ...       ...
# 2021-10-12 14:34:13  10.875184  45.919097      91.6
# 2021-10-12 14:34:20  10.875213  45.919122      91.6
# 2021-10-12 14:34:30  10.875186  45.919142      91.6
# 2021-10-12 14:35:45  10.875151  45.919126      91.6
# 2021-10-12 14:36:19  10.875091  45.919049      91.6
#
#                                                  geometry  traj_id      speed
# time
# 2021-10-12 12:01:38  POINT Z (10.84783 45.90022 96.50000)        1   5.026084
# 2021-10-12 12:01:39  POINT Z (10.84785 45.90026 96.50000)        1   5.026084
# 2021-10-12 12:01:40  POINT Z (10.84784 45.90013 96.50000)        1  15.459309
# 2021-10-12 12:01:41  POINT Z (10.84784 45.89989 96.50000)        1  26.125749
# 2021-10-12 12:01:42  POINT Z (10.84783 45.89979 96.50000)        1  11.559794
# ...                                                   ...      ...        ...
# 2021-10-12 14:34:13  POINT Z (10.87518 45.91910 91.60000)        1   0.765202
# 2021-10-12 14:34:20  POINT Z (10.87521 45.91912 91.60000)        1   0.510754
# 2021-10-12 14:34:30  POINT Z (10.87519 45.91914 91.60000)        1   0.305432
# 2021-10-12 14:35:45  POINT Z (10.87515 45.91913 91.60000)        1   0.043276
# 2021-10-12 14:36:19  POINT Z (10.87509 45.91905 91.60000)        1   0.286540
#
# [5532 rows x 6 columns]

# %%
# conversion m/s to km/h
def ms_to_km(ms):
    v = (ms) * (60*60)/1000
    return v

# %%
# km/h column
trajectory.df['kmh'] = trajectory.df['speed'].apply(ms_to_km)

# %%
trajectory.plot(column="kmh", linewidth=5, capstyle='round', legend=True)
plt.show()

# %% [markdown]
# ## Extracting a moving object's position was at a certain time

# %%
trajectory
# Out:
# Trajectory 1 (2021-10-12 12:01:38 to 2021-10-12 14:36:19) | Size: 5532 | Length: 40316.6m
# Bounds: (10.731099, 45.861882, 10.875513, 45.919142)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836

# %%
trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="nearest")
# Out:
# <POINT Z (10.841 45.889 81.1)>

# %%
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="nearest"))
# Out:
# POINT Z (10.840998 45.888594 81.1)

# %%
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="nearest"))
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="interpolated"))
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="ffill")) # from the previous row
print(trajectory.get_position_at(datetime(2021,10,12,12,6,0), method="bfill")) # from the following row
# Out:
# POINT Z (10.840998 45.888594 81.1)
# POINT Z (10.840998 45.888594 81.1)
# POINT Z (10.840998 45.888594 81.1)
# POINT Z (10.840998 45.888594 81.1)

# %% [markdown]
# ## Extracting trajectory segments based on time

# %%
segment_clip = trajectory.get_segment_between(datetime(2021,10,12,13,36,1),datetime(2021,10,12,13,38,51))
print(segment_clip)
# Out:
# Trajectory 1_2021-10-12 13:36:01 (2021-10-12 13:36:01 to 2021-10-12 13:38:49) | Size: 158 | Length: 1457.3m
# Bounds: (10.832986, 45.870462, 10.839058, 45.879066)
# LINESTRING Z (10.832986 45.870462 160.3, 10.833045 45.870534 159.9, 10.83311 45.870598 159.5, 10.833

# %%
segment_clip.plot()
plt.show()

# %% [markdown]
# ## Extracting trajectory segments based on  geometry (i.e. clipping)

# %%
from shapely.geometry import Point, Polygon
latitude=45.88880
longitude=10.84269
p = Point(longitude, latitude)
point = gpd.GeoDataFrame(pd.DataFrame(), 
    crs=4326,
    geometry= [p])
distance = 10 # meters
# create a bounding box
xmin, ymax, xmax, ymin = point.to_crs(epsg=32632).buffer(distance).geometry.to_crs(epsg=4326).iloc[0].bounds
polygon = Polygon([(xmin, ymin), (xmin, ymax), (xmax, ymax), (xmax, ymin), (xmin, ymin)])
polygon
# Out:
# <POLYGON ((10.843 45.889, 10.843 45.889, 10.843 45.889, 10.843 45.889, 10.84...>

# %%
intersections = trajectory.clip(polygon)
intersections
# Out:
# TrajectoryCollection with 3 trajectories

# %%
intersections.trajectories[0].plot(linewidth=5, capstyle='round')
plt.show()

# %%
intersections.trajectories[1].plot(linewidth=5, capstyle='round')
plt.show()

# %%
intersections.trajectories[2].plot(linewidth=5, capstyle='round')
plt.show()

# %% [markdown]
# ## Splitting trajectories
#
# Gaps are quite common in trajectories. For example, GPS tracks may contain gaps if moving objects enter tunnels where GPS reception is lost. In other use cases, moving objects may leave the observation area for longer time before returning and continuing their recorded track.
#
# Depending on the use case, we therefore might want to split trajectories at observation gaps that exceed a certain minimum duration:
#
# ### duration 15 minutes

# %%
split = mpd.ObservationGapSplitter(trajectory).split(gap=timedelta(minutes=15))
for traj in split:
    print(traj)
# Out:
# Trajectory 1_0 (2021-10-12 12:01:38 to 2021-10-12 13:47:11) | Size: 5070 | Length: 34131.1m
# Bounds: (10.731099, 45.861882, 10.84785, 45.901398)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836
# Trajectory 1_2 (2021-10-12 14:24:10 to 2021-10-12 14:36:19) | Size: 461 | Length: 6182.5m
# Bounds: (10.837456, 45.887391, 10.875513, 45.919142)
# LINESTRING Z (10.842638 45.888938 79.4, 10.842624 45.888947 79.5, 10.842587 45.888957 79.5, 10.84259

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(split), figsize=(19,4))
for i, traj in enumerate(split):
    traj.plot(ax=axes[i], linewidth=5.0, capstyle='round', column='speed', vmax=20)

# %% [markdown]
# 1Km

# %%
split = mpd.StopSplitter(trajectory).split(min_duration=timedelta(minutes=15), max_diameter=30, min_length=1000)
for traj in split:
    print(traj)
# Out:
# Trajectory 1_2021-10-12 12:01:38 (2021-10-12 12:01:38 to 2021-10-12 13:47:11) | Size: 5070 | Length: 34131.1m
# Bounds: (10.731099, 45.861882, 10.84785, 45.901398)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836
# Trajectory 1_2021-10-12 14:24:46 (2021-10-12 14:24:46 to 2021-10-12 14:36:19) | Size: 451 | Length: 6139.6m
# Bounds: (10.837456, 45.887391, 10.875513, 45.919142)
# LINESTRING Z (10.842474 45.889122 80.8, 10.842465 45.88916 80.9, 10.842435 45.889193 81.1, 10.842394

# %%
fig, axes = plt.subplots(nrows=1, ncols=len(split), figsize=(19,4))
for i, traj in enumerate(split):
    traj.plot(ax=axes[i], linewidth=5.0, capstyle='round', column='speed', vmax=20)

# %% [markdown]
# ## Stop detection

# %%
detector = mpd.TrajectoryStopDetector(trajectory)
# %time
# Out:
# CPU times: user 5 µs, sys: 0 ns, total: 5 µs
# Wall time: 9.3 µs

# %% [markdown]
# ### stop duration

# %%
stop_durations = detector.get_stop_time_ranges(min_duration=timedelta(seconds=60), max_diameter=100)
# %%time
# Out:
# UsageError: Line magic function `%%time` not found.

# %%
for x in stop_durations: 
    print(x)
# Out:
# Traj 1: 2021-10-12 12:31:48 - 2021-10-12 12:32:48 (duration: 0 days 00:01:00)
# Traj 1: 2021-10-12 12:45:36 - 2021-10-12 12:46:40 (duration: 0 days 00:01:04)
# Traj 1: 2021-10-12 12:46:49 - 2021-10-12 12:47:49 (duration: 0 days 00:01:00)
# Traj 1: 2021-10-12 12:47:51 - 2021-10-12 12:49:08 (duration: 0 days 00:01:17)
# Traj 1: 2021-10-12 12:50:03 - 2021-10-12 12:51:06 (duration: 0 days 00:01:03)
# Traj 1: 2021-10-12 12:51:09 - 2021-10-12 12:52:45 (duration: 0 days 00:01:36)
# Traj 1: 2021-10-12 13:41:59 - 2021-10-12 14:25:54 (duration: 0 days 00:43:55)
# Traj 1: 2021-10-12 14:34:30 - 2021-10-12 14:36:19 (duration: 0 days 00:01:49)

# %% [markdown]
# ## stop points

# %%
# %%time
stop_points = detector.get_stop_points(min_duration=timedelta(seconds=60), max_diameter=100)
# Out:
# CPU times: user 1.61 s, sys: 1 µs, total: 1.61 s
# Wall time: 1.62 s

# %%
stop_points
# Out:
#                                         geometry          start_time  \
# stop_id
# 1_2021-10-12 12:31:48  POINT (10.81310 45.86407) 2021-10-12 12:31:48
# 1_2021-10-12 12:45:36  POINT (10.78240 45.86788) 2021-10-12 12:45:36
# 1_2021-10-12 12:46:49  POINT (10.78177 45.86865) 2021-10-12 12:46:49
# 1_2021-10-12 12:47:51  POINT (10.78148 45.86949) 2021-10-12 12:47:51
# 1_2021-10-12 12:50:03  POINT (10.77875 45.86941) 2021-10-12 12:50:03
# 1_2021-10-12 12:51:09  POINT (10.77797 45.86928) 2021-10-12 12:51:09
# 1_2021-10-12 13:41:59  POINT (10.84250 45.88896) 2021-10-12 13:41:59
# 1_2021-10-12 14:34:30  POINT (10.87515 45.91913) 2021-10-12 14:34:30
#
#                                  end_time  traj_id  duration_s
# stop_id
# 1_2021-10-12 12:31:48 2021-10-12 12:32:48        1        60.0
# 1_2021-10-12 12:45:36 2021-10-12 12:46:40        1        64.0
# 1_2021-10-12 12:46:49 2021-10-12 12:47:49        1        60.0
# 1_2021-10-12 12:47:51 2021-10-12 12:49:08        1        77.0
# 1_2021-10-12 12:50:03 2021-10-12 12:51:06        1        63.0
# 1_2021-10-12 12:51:09 2021-10-12 12:52:45        1        96.0
# 1_2021-10-12 13:41:59 2021-10-12 14:25:54        1      2635.0
# 1_2021-10-12 14:34:30 2021-10-12 14:36:19        1       109.0

# %% [markdown]
# ## stop segments

# %%
# %%time
stops = detector.get_stop_segments(min_duration=timedelta(seconds=60), max_diameter=100)
# Out:
# CPU times: user 1.48 s, sys: 0 ns, total: 1.48 s
# Wall time: 1.48 s

# %%
stops
# Out:
# TrajectoryCollection with 8 trajectories

# %% [markdown]
# ## split a stop

# %%
# %%time
split = mpd.StopSplitter(trajectory).split(min_duration=timedelta(seconds=60), max_diameter=100)
# Out:
# CPU times: user 1.86 s, sys: 41 µs, total: 1.86 s
# Wall time: 1.86 s

# %%
split
# Out:
# TrajectoryCollection with 8 trajectories

# %%
for segment in split:
    print(segment)
# Out:
# Trajectory 1_2021-10-12 12:01:38 (2021-10-12 12:01:38 to 2021-10-12 12:31:48) | Size: 1393 | Length: 8328.3m
# Bounds: (10.813493, 45.861981, 10.84785, 45.901398)
# LINESTRING Z (10.847826 45.900222 96.5, 10.84785 45.900264 96.5, 10.847843 45.900125 96.5, 10.847836
# Trajectory 1_2021-10-12 12:32:48 (2021-10-12 12:32:48 to 2021-10-12 12:45:36) | Size: 620 | Length: 2836.8m
# Bounds: (10.782862, 45.863908, 10.812408, 45.867858)
# LINESTRING Z (10.812408 45.864088 383.4, 10.812352 45.864073 383.8, 10.812289 45.864066 384.1, 10.81
# Trajectory 1_2021-10-12 12:46:40 (2021-10-12 12:46:40 to 2021-10-12 12:46:49) | Size: 5 | Length: 17.1m
# Bounds: (10.782128, 45.868145, 10.782239, 45.868274)
# LINESTRING Z (10.782239 45.868145 533, 10.782199 45.868181 533.4, 10.782169 45.868201 533.7, 10.7821
# Trajectory 1_2021-10-12 12:47:49 (2021-10-12 12:47:49 to 2021-10-12 12:47:51) | Size: 2 | Length: 3.1m
# Bounds: (10.781568, 45.869024, 10.781579, 45.869051)
# LINESTRING Z (10.781568 45.869024 548.5, 10.781579 45.869051 549)
# Trajectory 1_2021-10-12 12:49:08 (2021-10-12 12:49:08 to 2021-10-12 12:50:03) | Size: 29 | Length: 115.2m
# Bounds: (10.779572, 45.869424, 10.780837, 45.869678)
# LINESTRING Z (10.780837 45.869494 567, 10.780793 45.8695 567.5, 10.780755 45.869504 567.9, 10.780741
# Trajectory 1_2021-10-12 12:51:06 (2021-10-12 12:51:06 to 2021-10-12 12:51:09) | Size: 2 | Length: 4.7m
# Bounds: (10.778313, 45.869304, 10.778364, 45.869326)
# LINESTRING Z (10.778364 45.869326 592.4, 10.778313 45.869304 592.9)
# Trajectory 1_2021-10-12 12:52:45 (2021-10-12 12:52:45 to 2021-10-12 13:41:59) | Size: 2809 | Length: 21943.9m
# Bounds: (10.731099, 45.861882, 10.842706, 45.888921)
# LINESTRING Z (10.7771 45.869327 613.5, 10.77706 45.869333 613.9, 10.77702 45.869337 614.4, 10.77698
# Trajectory 1_2021-10-12 14:25:54 (2021-10-12 14:25:54 to 2021-10-12 14:34:30) | Size: 418 | Length: 5957.6m
# Bounds: (10.837456, 45.887391, 10.875513, 45.919142)
# LINESTRING Z (10.841589 45.888575 80.3, 10.841491 45.888581 80.4, 10.841386 45.888567 80.6, 10.84124

# %% [markdown]
# ## Generalizing trajectories
#
# ### Douglas-Peucker algorithm

# %%
trajectory.plot(column='speed', linewidth=5, capstyle='round', figsize=(9,3), legend=True, vmax=20)
plt.show()

# %%
generalized_trajectory = mpd.DouglasPeuckerGeneralizer(trajectory).generalize(tolerance=0.001)
generalized_trajectory.plot(column='speed', linewidth=5, capstyle='round', figsize=(9,3), legend=True, vmax=20)
plt.show()

# %%
print('Original length: %s'%(trajectory.get_length()))
print('Generalized length: %s'%(generalized_trajectory.get_length()))
# Out:
# Original length: 40316.62984538985
# Generalized length: 34969.98458540832

# %% [markdown]
# ###  alternative down-sample the trajectory to ensure a certain time delta between records

# %%
time_generalized = mpd.MinTimeDeltaGeneralizer(trajectory).generalize(tolerance=timedelta(minutes=10))
time_generalized.plot(column='speed', linewidth=5, capstyle='round', figsize=(9,3), legend=True, vmax=20)
plt.show()

# %%
time_generalized.to_point_gdf().head(10)
# Out:
#                      longitude   latitude  altitude  \
# time
# 2021-10-12 12:01:38  10.847826  45.900222      96.5
# 2021-10-12 12:11:38  10.837393  45.874687     118.6
# 2021-10-12 12:21:38  10.830129  45.862466     244.0
# 2021-10-12 12:31:38  10.813936  45.864505     371.3
# 2021-10-12 12:41:38  10.788925  45.865013     477.9
# 2021-10-12 12:51:39  10.778118  45.869216     598.4
# 2021-10-12 13:01:39  10.746818  45.869637     657.8
# 2021-10-12 13:11:39  10.741853  45.885748     656.5
# 2021-10-12 13:21:39  10.774246  45.870862     637.8
# 2021-10-12 13:31:39  10.827858  45.863224     301.4
#
#                                                   geometry  traj_id  \
# time
# 2021-10-12 12:01:38   POINT Z (10.84783 45.90022 96.50000)        1
# 2021-10-12 12:11:38  POINT Z (10.83739 45.87469 118.60000)        1
# 2021-10-12 12:21:38  POINT Z (10.83013 45.86247 244.00000)        1
# 2021-10-12 12:31:38  POINT Z (10.81394 45.86451 371.30000)        1
# 2021-10-12 12:41:38  POINT Z (10.78893 45.86501 477.90000)        1
# 2021-10-12 12:51:39  POINT Z (10.77812 45.86922 598.40000)        1
# 2021-10-12 13:01:39  POINT Z (10.74682 45.86964 657.80000)        1
# 2021-10-12 13:11:39  POINT Z (10.74185 45.88575 656.50000)        1
# 2021-10-12 13:21:39  POINT Z (10.77425 45.87086 637.80000)        1
# 2021-10-12 13:31:39  POINT Z (10.82786 45.86322 301.40000)        1
#
#                          speed        kmh
# time
# 2021-10-12 12:01:38   5.026084  18.093904
# 2021-10-12 12:11:38   4.446633  16.007878
# 2021-10-12 12:21:38   3.863094  13.907137
# 2021-10-12 12:31:38   3.815148  13.734534
# 2021-10-12 12:41:38   3.525257  12.690925
# 2021-10-12 12:51:39   1.619121   5.828837
# 2021-10-12 13:01:39   8.849716  31.858976
# 2021-10-12 13:11:39   6.003111  21.611198
# 2021-10-12 13:21:39  10.406578  37.463682
# 2021-10-12 13:31:39  10.652206  38.347942

# %% [markdown]
# ---
#
# # Exercise
#
# - identify the shortest path by walk to reach the Castle of Trento from the main train station of Trento
# - identify the streets network orientation of the cities: Trento-Italy, Verona-Italy,  Munich-Germany, Athens-Greece
# - locate the student residences of Trento in OpenStreetMap and identify services in an area of 15 minutes based on the concept of [Carlos Moreno](https://twitter.com/CarlosMorenoFr) of [the 15 minute city](https://www.ted.com/talks/carlos_moreno_the_15_minute_city)<br/>
# <i>"...a way to ensure that urban residents can fulfill six essential functions within a 15-minute walk [or bike] from their dwellings: living, working, commerce, healthcare, education and entertainment..."</i>
